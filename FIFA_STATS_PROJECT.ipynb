# %%
# Importing Libraries
import pandas as pd 
import numpy as np 
import seaborn as sns 
from matplotlib import pyplot as plt

# %% [markdown]
# <span style="font-size:24px ; color:red;">STEP 1 : UNDERSTANDING THE DATA.</span>

# %%
df = pd.read_csv("fifa_case.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0               Name  Age  Overall Nationality  \
# 0           0           L. Messi   31       94   Argentina
# 1           1  Cristiano Ronaldo   33       94    Portugal
# 2           2          Neymar Jr   26       92      Brazil
# 3           3             De Gea   27       91       Spain
# 4           4       K. De Bruyne   27       91     Belgium
# 5           5          E. Hazard   27       91     Belgium
# 6           6          L. Modrić   32       91     Croatia
# 7           7          L. Suárez   31       91     Uruguay
# 8           8       Sergio Ramos   32       91       Spain
# 9           9           J. Oblak   25       90    Slovenia
#
#                                   Flag  LongPassing                 Club  \
# 0  https://cdn.sofifa.org/flags/52.png         87.0         FC Barcelona
# 1  https://cdn.sofifa.org/flags/38.png         77.0             Juventus
# 2  https://cdn.sofifa.org/flags/54.png         78.0  Paris Saint-Germain
# 3  https://cdn.sofifa.org/flags/45.png         51.0    Manchester United
# 4   https://cdn.sofifa.org/flags/7.png         91.0      Manchester City
# 5   https://cdn.sofifa.org/flags/7.png         83.0              Chelsea
# 6  https://cdn.sofifa.org/flags/10.png         88.0          Real Madrid
# 7  https://cdn.sofifa.org/flags/60.png         64.0         FC Barcelona
# 8  https://cdn.sofifa.org/flags/45.png         77.0          Real Madrid
# 9  https://cdn.sofifa.org/flags/44.png         26.0      Atlético Madrid
#
#    BallControl  Acceleration  ...  GKReflexes  Position  Crossing  Volleys  \
# 0         96.0          91.0  ...         8.0        RF      84.0     86.0
# 1         94.0          89.0  ...        11.0        ST      84.0     87.0
# 2         95.0          94.0  ...        11.0        LW      79.0     84.0
# 3         42.0          57.0  ...        94.0        GK      17.0     13.0
# 4         91.0          78.0  ...        13.0       RCM      93.0     82.0
# 5         94.0          94.0  ...         8.0        LF      81.0     80.0
# 6         93.0          80.0  ...         9.0       RCM      86.0     76.0
# 7         90.0          86.0  ...        37.0        RS      77.0     88.0
# 8         84.0          76.0  ...        11.0       RCB      66.0     66.0
# 9         16.0          43.0  ...        89.0        GK      13.0     13.0
#
#    HeadingAccuracy  ShortPassing  FKAccuracy  Finishing  Curve  Dribbling
# 0             70.0          90.0        94.0       95.0   93.0       97.0
# 1             89.0          81.0        76.0       94.0   81.0       88.0
# 2             62.0          84.0        87.0       87.0   88.0       96.0
# 3             21.0          50.0        19.0       13.0   21.0       18.0
# 4             55.0          92.0        83.0       82.0   85.0       86.0
# 5             61.0          89.0        79.0       84.0   83.0       95.0
# 6             55.0          93.0        78.0       72.0   85.0       90.0
# 7             77.0          82.0        84.0       93.0   86.0       87.0
# 8             91.0          78.0        72.0       60.0   74.0       63.0
# 9             15.0          29.0        14.0       11.0   13.0       12.0
#
# [10 rows x 42 columns]

# %%
df.shape
# Out:
# (18207, 42)

# %%
df.describe()
# Out:
#          Unnamed: 0           Age       Overall   LongPassing   BallControl  \
# count  18207.000000  18207.000000  18207.000000  18159.000000  18159.000000
# mean    9103.000000     25.122206     66.238699     52.711933     58.369459
# std     5256.052511      4.669943      6.908930     15.327870     16.686595
# min        0.000000     16.000000     46.000000      9.000000      5.000000
# 25%     4551.500000     21.000000     62.000000     43.000000     54.000000
# 50%     9103.000000     25.000000     66.000000     56.000000     63.000000
# 75%    13654.500000     28.000000     71.000000     64.000000     69.000000
# max    18206.000000     45.000000     94.000000     93.000000     96.000000
#
#        Acceleration   SprintSpeed       Agility     Reactions       Balance  \
# count  18159.000000  18159.000000  18159.000000  18159.000000  18159.000000
# mean      64.614076     64.726967     63.503607     61.836610     63.966573
# std       14.927780     14.649953     14.766049      9.010464     14.136166
# min       12.000000     12.000000     14.000000     21.000000     16.000000
# 25%       57.000000     57.000000     55.000000     56.000000     56.000000
# 50%       67.000000     67.000000     66.000000     62.000000     66.000000
# 75%       75.000000     75.000000     74.000000     68.000000     74.000000
# max       97.000000     96.000000     96.000000     96.000000     96.000000
#
#        ...  GKPositioning    GKReflexes      Crossing       Volleys  \
# count  ...   18159.000000  18159.000000  18159.000000  18159.000000
# mean   ...      16.388898     16.710887     49.734181     42.909026
# std    ...      17.034669     17.955119     18.364524     17.694408
# min    ...       1.000000      1.000000      5.000000      4.000000
# 25%    ...       8.000000      8.000000     38.000000     30.000000
# 50%    ...      11.000000     11.000000     54.000000     44.000000
# 75%    ...      14.000000     14.000000     64.000000     57.000000
# max    ...      90.000000     94.000000     93.000000     90.000000
#
#        HeadingAccuracy  ShortPassing    FKAccuracy     Finishing  \
# count     18159.000000  18159.000000  18159.000000  18159.000000
# mean         52.298144     58.686712     42.863153     45.550911
# std          17.379909     14.699495     17.478763     19.525820
# min           4.000000      7.000000      3.000000      2.000000
# 25%          44.000000     54.000000     31.000000     30.000000
# 50%          56.000000     62.000000     41.000000     49.000000
# 75%          64.000000     68.000000     57.000000     62.000000
# max          94.000000     93.000000     94.000000     95.000000
#
#               Curve     Dribbling
# count  18159.000000  18159.000000
# mean      47.170824     55.371001
# std       18.395264     18.910371
# min        6.000000      4.000000
# 25%       34.000000     49.000000
# 50%       48.000000     61.000000
# 75%       62.000000     68.000000
# max       94.000000     97.000000
#
# [8 rows x 37 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18207 entries, 0 to 18206
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18207 non-null  int64
#  1   Name             18207 non-null  object
#  2   Age              18207 non-null  int64
#  3   Overall          18207 non-null  int64
#  4   Nationality      18207 non-null  object
#  5   Flag             18207 non-null  object
#  6   LongPassing      18159 non-null  float64
#  7   Club             17966 non-null  object
#  8   BallControl      18159 non-null  float64
#  9   Acceleration     18159 non-null  float64
#  10  SprintSpeed      18159 non-null  float64
#  11  Agility          18159 non-null  float64
#  12  Reactions        18159 non-null  float64
#  13  Balance          18159 non-null  float64
#  14  ShotPower        18159 non-null  float64
#  15  Jumping          18159 non-null  float64
#  16  Stamina          18159 non-null  float64
#  17  Strength         18159 non-null  float64
#  18  LongShots        18159 non-null  float64
#  19  Aggression       18159 non-null  float64
#  20  Interceptions    18159 non-null  float64
#  21  Positioning      18159 non-null  float64
#  22  Vision           18159 non-null  float64
#  23  Penalties        18159 non-null  float64
#  24  Composure        18159 non-null  float64
#  25  Marking          18159 non-null  float64
#  26  StandingTackle   18159 non-null  float64
#  27  SlidingTackle    18159 non-null  float64
#  28  GKDiving         18159 non-null  float64
#  29  GKHandling       18159 non-null  float64
#  30  GKKicking        18159 non-null  float64
#  31  GKPositioning    18159 non-null  float64
#  32  GKReflexes       18159 non-null  float64
#  33  Position         18147 non-null  object
#  34  Crossing         18159 non-null  float64
#  35  Volleys          18159 non-null  float64
#  36  HeadingAccuracy  18159 non-null  float64
#  37  ShortPassing     18159 non-null  float64
#  38  FKAccuracy       18159 non-null  float64
#  39  Finishing        18159 non-null  float64
#  40  Curve            18159 non-null  float64
#  41  Dribbling        18159 non-null  float64
# dtypes: float64(34), int64(3), object(5)
# memory usage: 5.8+ MB

# %%
df.value_counts()
# Out:
# Unnamed: 0  Name            Age  Overall  Nationality  Flag                                  LongPassing  Club                      BallControl  Acceleration  SprintSpeed  Agility  Reactions  Balance  ShotPower  Jumping  Stamina  Strength  LongShots  Aggression  Interceptions  Positioning  Vision  Penalties  Composure  Marking  StandingTackle  SlidingTackle  GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes  Position  Crossing  Volleys  HeadingAccuracy  ShortPassing  FKAccuracy  Finishing  Curve  Dribbling
# 0           L. Messi        31   94       Argentina    https://cdn.sofifa.org/flags/52.png   87.0         FC Barcelona              96.0         91.0          86.0         91.0     95.0       95.0     85.0       68.0     72.0     59.0      94.0       48.0        22.0           94.0         94.0    75.0       96.0       33.0     28.0            26.0           6.0       11.0        15.0       14.0           8.0         RF        84.0      86.0     70.0             90.0          94.0        95.0       93.0   97.0         1
# 12127       K. Nagato       23   63       Japan        https://cdn.sofifa.org/flags/163.png  58.0         Vegalta Sendai            61.0         74.0          70.0         64.0     46.0       79.0     56.0       72.0     76.0     57.0      24.0       54.0        62.0           60.0         60.0    36.0       54.0       57.0     65.0            61.0           7.0       14.0        6.0        7.0            11.0        LM        73.0      22.0     36.0             61.0          54.0        41.0       62.0   60.0         1
# 12133       Sander Asevedo  34   63       Brazil       https://cdn.sofifa.org/flags/54.png   12.0         Paraná                    10.0         41.0          48.0         39.0     71.0       40.0     9.0        50.0     51.0     76.0      6.0        47.0        10.0           8.0          59.0    18.0       58.0       25.0     11.0            14.0           68.0      59.0        47.0       60.0           58.0        GK        10.0      9.0      11.0             17.0          16.0        7.0        13.0   8.0          1
# 12132       H. Hallberg     21   63       Sweden       https://cdn.sofifa.org/flags/46.png   58.0         Kalmar FF                 63.0         71.0          65.0         72.0     63.0       68.0     67.0       58.0     81.0     68.0      59.0       78.0        63.0           62.0         61.0    48.0       58.0       40.0     50.0            41.0           8.0       15.0        14.0       12.0           12.0        CM        59.0      46.0     39.0             62.0          41.0        48.0       54.0   61.0         1
# 12131       R. Maeda        36   63       Japan        https://cdn.sofifa.org/flags/163.png  61.0         FC Tokyo                  64.0         33.0          52.0         59.0     60.0       41.0     66.0       68.0     48.0     65.0      63.0       63.0        57.0           68.0         61.0    66.0       64.0       54.0     43.0            44.0           9.0       13.0        11.0       11.0           7.0         ST        51.0      60.0     69.0             67.0          65.0        62.0       61.0   59.0         1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            ..
# 6078        M. Tanković     23   69       Sweden       https://cdn.sofifa.org/flags/46.png   54.0         Hammarby IF               71.0         77.0          73.0         73.0     65.0       75.0     67.0       73.0     80.0     66.0      63.0       61.0        31.0           70.0         69.0    67.0       67.0       45.0     20.0            24.0           7.0       12.0        9.0        10.0           11.0        CAM       58.0      58.0     62.0             65.0          56.0        64.0       65.0   69.0         1
# 6079        R. Lindgren     33   69       Sweden       https://cdn.sofifa.org/flags/46.png   63.0         BK Häcken                 67.0         48.0          32.0         62.0     72.0       71.0     70.0       41.0     74.0     73.0      74.0       73.0        70.0           52.0         58.0    68.0       69.0       66.0     72.0            69.0           7.0       11.0        7.0        16.0           8.0         RCB       65.0      69.0     65.0             66.0          74.0        53.0       68.0   58.0         1
# 6080        Raúl Llorente   32   69       Spain        https://cdn.sofifa.org/flags/45.png   56.0         Western Sydney Wanderers  63.0         81.0          80.0         75.0     55.0       91.0     66.0       86.0     85.0     64.0      39.0       74.0        62.0           65.0         46.0    32.0       56.0       61.0     66.0            72.0           10.0      14.0        10.0       6.0            9.0         LB        70.0      38.0     57.0             65.0          30.0        24.0       55.0   59.0         1
# 6081        M. García       26   69       Argentina    https://cdn.sofifa.org/flags/52.png   63.0         San Martin de Tucumán     67.0         77.0          82.0         73.0     63.0       77.0     50.0       64.0     88.0     62.0      47.0       69.0        49.0           68.0         65.0    44.0       66.0       40.0     53.0            50.0           14.0      13.0        14.0       12.0           10.0        LM        62.0      38.0     51.0             67.0          45.0        55.0       64.0   70.0         1
# 18206       G. Nugent       16   46       England      https://cdn.sofifa.org/flags/14.png   44.0         Tranmere Rovers           51.0         57.0          55.0         55.0     51.0       63.0     43.0       62.0     47.0     60.0      32.0       56.0        42.0           34.0         49.0    33.0       43.0       40.0     43.0            50.0           10.0      15.0        9.0        12.0           9.0         CM        41.0      30.0     46.0             48.0          34.0        34.0       40.0   43.0         1
# Name: count, Length: 17918, dtype: int64

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Name', 'Age', 'Overall', 'Nationality', 'Flag',
#        'LongPassing', 'Club', 'BallControl', 'Acceleration', 'SprintSpeed',
#        'Agility', 'Reactions', 'Balance', 'ShotPower', 'Jumping', 'Stamina',
#        'Strength', 'LongShots', 'Aggression', 'Interceptions', 'Positioning',
#        'Vision', 'Penalties', 'Composure', 'Marking', 'StandingTackle',
#        'SlidingTackle', 'GKDiving', 'GKHandling', 'GKKicking', 'GKPositioning',
#        'GKReflexes', 'Position', 'Crossing', 'Volleys', 'HeadingAccuracy',
#        'ShortPassing', 'FKAccuracy', 'Finishing', 'Curve', 'Dribbling'],
#       dtype='object')

# %% [markdown]
# <span style="font-size:24px ; color:red;">STEP 2 : HANDLING MISSING AND DUPLICATE DATA.</span>

# %%
# looking for null values 
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Age                  0
# Overall              0
# Nationality          0
# Flag                 0
# LongPassing         48
# Club               241
# BallControl         48
# Acceleration        48
# SprintSpeed         48
# Agility             48
# Reactions           48
# Balance             48
# ShotPower           48
# Jumping             48
# Stamina             48
# Strength            48
# LongShots           48
# Aggression          48
# Interceptions       48
# Positioning         48
# Vision              48
# Penalties           48
# Composure           48
# Marking             48
# StandingTackle      48
# SlidingTackle       48
# GKDiving            48
# GKHandling          48
# GKKicking           48
# GKPositioning       48
# GKReflexes          48
# Position            60
# Crossing            48
# Volleys             48
# HeadingAccuracy     48
# ShortPassing        48
# FKAccuracy          48
# Finishing           48
# Curve               48
# Dribbling           48
# dtype: int64

# %%
# looking for duplicated values
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Name, Age, Overall, Nationality, Flag, LongPassing, Club, BallControl, Acceleration, SprintSpeed, Agility, Reactions, Balance, ShotPower, Jumping, Stamina, Strength, LongShots, Aggression, Interceptions, Positioning, Vision, Penalties, Composure, Marking, StandingTackle, SlidingTackle, GKDiving, GKHandling, GKKicking, GKPositioning, GKReflexes, Position, Crossing, Volleys, HeadingAccuracy, ShortPassing, FKAccuracy, Finishing, Curve, Dribbling]
# Index: []
#
# [0 rows x 42 columns]

# %%
# checking unique column because we dont have enough info about that column
df["Unnamed: 0"].unique()
# Out:
# array([    0,     1,     2, ..., 18204, 18205, 18206], dtype=int64)

# %%
df.drop(columns=["Unnamed: 0"])
# Out:
#                      Name  Age  Overall Nationality  \
# 0                L. Messi   31       94   Argentina
# 1       Cristiano Ronaldo   33       94    Portugal
# 2               Neymar Jr   26       92      Brazil
# 3                  De Gea   27       91       Spain
# 4            K. De Bruyne   27       91     Belgium
# ...                   ...  ...      ...         ...
# 18202        J. Lundstram   19       47     England
# 18203  N. Christoffersson   19       47      Sweden
# 18204           B. Worman   16       47     England
# 18205      D. Walker-Rice   17       47     England
# 18206           G. Nugent   16       46     England
#
#                                       Flag  LongPassing                 Club  \
# 0      https://cdn.sofifa.org/flags/52.png         87.0         FC Barcelona
# 1      https://cdn.sofifa.org/flags/38.png         77.0             Juventus
# 2      https://cdn.sofifa.org/flags/54.png         78.0  Paris Saint-Germain
# 3      https://cdn.sofifa.org/flags/45.png         51.0    Manchester United
# 4       https://cdn.sofifa.org/flags/7.png         91.0      Manchester City
# ...                                    ...          ...                  ...
# 18202  https://cdn.sofifa.org/flags/14.png         45.0      Crewe Alexandra
# 18203  https://cdn.sofifa.org/flags/46.png         25.0       Trelleborgs FF
# 18204  https://cdn.sofifa.org/flags/14.png         28.0     Cambridge United
# 18205  https://cdn.sofifa.org/flags/14.png         32.0      Tranmere Rovers
# 18206  https://cdn.sofifa.org/flags/14.png         44.0      Tranmere Rovers
#
#        BallControl  Acceleration  SprintSpeed  ...  GKReflexes  Position  \
# 0             96.0          91.0         86.0  ...         8.0        RF
# 1             94.0          89.0         91.0  ...        11.0        ST
# 2             95.0          94.0         90.0  ...        11.0        LW
# 3             42.0          57.0         58.0  ...        94.0        GK
# 4             91.0          78.0         76.0  ...        13.0       RCM
# ...            ...           ...          ...  ...         ...       ...
# 18202         43.0          54.0         57.0  ...         9.0        CM
# 18203         40.0          41.0         39.0  ...        12.0        ST
# 18204         44.0          70.0         69.0  ...        13.0        ST
# 18205         52.0          61.0         60.0  ...         9.0        RW
# 18206         51.0          57.0         55.0  ...         9.0        CM
#
#        Crossing  Volleys  HeadingAccuracy  ShortPassing  FKAccuracy  \
# 0          84.0     86.0             70.0          90.0        94.0
# 1          84.0     87.0             89.0          81.0        76.0
# 2          79.0     84.0             62.0          84.0        87.0
# 3          17.0     13.0             21.0          50.0        19.0
# 4          93.0     82.0             55.0          92.0        83.0
# ...         ...      ...              ...           ...         ...
# 18202      34.0     25.0             40.0          49.0        34.0
# 18203      23.0     36.0             52.0          43.0        20.0
# 18204      25.0     38.0             46.0          38.0        27.0
# 18205      44.0     40.0             39.0          42.0        32.0
# 18206      41.0     30.0             46.0          48.0        34.0
#
#        Finishing  Curve  Dribbling
# 0           95.0   93.0       97.0
# 1           94.0   81.0       88.0
# 2           87.0   88.0       96.0
# 3           13.0   21.0       18.0
# 4           82.0   85.0       86.0
# ...          ...    ...        ...
# 18202       38.0   30.0       42.0
# 18203       52.0   32.0       39.0
# 18204       40.0   38.0       45.0
# 18205       50.0   34.0       51.0
# 18206       34.0   40.0       43.0
#
# [18207 rows x 41 columns]

# %%
# droping the missing float values in all columns
float_columns_with_missing_values = df.select_dtypes(include="float64").columns[df.select_dtypes(include="float64").isnull().any()]

missing_values_count_per_column = df[float_columns_with_missing_values].isnull().sum()

float_columns_with_missing_values
missing_values_count_per_column
# Out:
# LongPassing        48
# BallControl        48
# Acceleration       48
# SprintSpeed        48
# Agility            48
# Reactions          48
# Balance            48
# ShotPower          48
# Jumping            48
# Stamina            48
# Strength           48
# LongShots          48
# Aggression         48
# Interceptions      48
# Positioning        48
# Vision             48
# Penalties          48
# Composure          48
# Marking            48
# StandingTackle     48
# SlidingTackle      48
# GKDiving           48
# GKHandling         48
# GKKicking          48
# GKPositioning      48
# GKReflexes         48
# Crossing           48
# Volleys            48
# HeadingAccuracy    48
# ShortPassing       48
# FKAccuracy         48
# Finishing          48
# Curve              48
# Dribbling          48
# dtype: int64

# %%
df.dropna(subset=df.select_dtypes(include='float64').columns, inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0           0
# Name                 0
# Age                  0
# Overall              0
# Nationality          0
# Flag                 0
# LongPassing          0
# Club               241
# BallControl          0
# Acceleration         0
# SprintSpeed          0
# Agility              0
# Reactions            0
# Balance              0
# ShotPower            0
# Jumping              0
# Stamina              0
# Strength             0
# LongShots            0
# Aggression           0
# Interceptions        0
# Positioning          0
# Vision               0
# Penalties            0
# Composure            0
# Marking              0
# StandingTackle       0
# SlidingTackle        0
# GKDiving             0
# GKHandling           0
# GKKicking            0
# GKPositioning        0
# GKReflexes           0
# Position            12
# Crossing             0
# Volleys              0
# HeadingAccuracy      0
# ShortPassing         0
# FKAccuracy           0
# Finishing            0
# Curve                0
# Dribbling            0
# dtype: int64
